# %%
from fastai.vision.all import *
from fastai.text.all import *

# %%
path=untar_data(URLs.IMAGENETTE_160)

# %%
dls=DataBlock(blocks=(ImageBlock,CategoryBlock),
          get_items=get_image_files,
          item_tfms=CropPad(160,PadMode.Reflection),
          splitter=GrandparentSplitter(),
          get_y = parent_label
).dataloaders(path)

# %%
dls.show_batch()

# %%
UnetBlock??

# %%
CategoryBlock??

# %%
Categorize??

# %%
_TfmMeta??
# Out:
# Object `_TfmMeta` not found.

# %%
Pad_Chunk
# Out:
# fastai.text.data.Pad_Chunk

# %%
pdb pdd command
